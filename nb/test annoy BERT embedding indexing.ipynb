# %%
from trialstreamer import PICO_search

# %%
PICO_search.build_annoy_indices()
# Out:
# on iter 0
# ...
# iter 9 (9000 done): 100%|██████████| 1000/1000 [00:00<00:00, 5906.76it/s]
# on iter 10
# ...
# iter 19 (19000 done): 100%|██████████| 1000/1000 [00:00<00:00, 6742.17it/s]
# on iter 20
# ...
# iter 29 (29000 done): 100%|██████████| 1000/1000 [00:00<00:00, 5405.33it/s]
# on iter 30
# ...
# iter 39 (39000 done): 100%|██████████| 1000/1000 [00:00<00:00, 6708.99it/s]
# on iter 40
# ...
# iter 49 (49000 done): 100%|██████████| 1000/1000 [00:00<00:00, 4598.39it/s]
# on iter 50
# ...
# iter 59 (59000 done): 100%|██████████| 1000/1000 [00:00<00:00, 6635.16it/s]
# on iter 60
# ...
# iter 69 (69000 done): 100%|██████████| 1000/1000 [00:00<00:00, 6744.21it/s]
# on iter 70
# ...
# iter 79 (79000 done): 100%|██████████| 1000/1000 [00:00<00:00, 4570.18it/s]
# on iter 80
# ...
# iter 89 (89000 done): 100%|██████████| 1000/1000 [00:00<00:00, 6575.03it/s]
# on iter 90
# ...
# iter 99 (99000 done): 100%|██████████| 1000/1000 [00:00<00:00, 6661.73it/s]
# on iter 100
# ...

# %%
PICO_search.t_p
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-77bc90e8a081> in <module>
# ----> 1 PICO_search.t_p
#
# AttributeError: module 'trialstreamer.PICO_search' has no attribute 't_p'
